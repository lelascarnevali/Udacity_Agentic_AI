# %% [markdown]
# # [STARTER] Exercise - Building an AI Agent with Tools
#
# In this exercise, you'll build an AI agent that can use tools to enhance its capabilities. You'll learn how to create an agent that can understand when to use tools, process their results, and maintain a coherent conversation.

# %% [markdown]
# ## Challenge
#
# Imagine you're building a smart coding assistant that needs to:
# - Answer programming questions
# - Execute code snippets
# - Look up documentation
# - Perform calculations
# - Search through codebases
#
# Instead of hard-coding when to use each capability, your agent should intelligently decide when and how to use its available tools.

# %% [markdown]
# ## Setup
# First, let's import the necessary libraries:

# %%
from typing import List, Dict, Any
from dotenv import load_dotenv
from copy import deepcopy
import json

from lib.messages import UserMessage, SystemMessage, ToolMessage
from lib.tooling import tool
from lib.llm import LLM

# %% [markdown]
# ## Understanding the Components
#
# Before we build our agent, let's understand the key components we'll be working with:
#
# - `LLM`: The language model wrapper that handles tool execution
# - `SystemMessage`: Defines the agent's role and behavior
# - `UserMessage`: Represents user inputs
# - `ToolMessage`: Contains tool execution results
# - `tool`: Decorator for creating tools

# %% [markdown]
# ## Building the Agent Class
#
# Your task is to create an Agent class that can:
# 1. Initialize with a specific role and set of tools
# 2. Process user messages
# 3. Decide when to use tools
# 4. Handle tool responses

# %%
from operator import call

from babel import messages


class Agent:
    """An AI Agent that can use tools to help answer questions"""

    def __init__(
        self,
        role: str = "Personal Assistant",
        instructions: str = "Help users with any question",
        model: str = "gpt-4o-mini",
        temperature: float = 0.0,
        tools: List[Any] = None
    ):
        """Initialize the agent with its configuration and tools"""
        load_dotenv()
        self.role = role
        self.instructions = instructions
        self.model = model
        self.temperature = temperature
        self.tools = tools or []
        self.llm = LLM(model=self.model, temperature=self.temperature, tools=self.tools)

    def invoke(self, user_message: str) -> str:
        """Process a user message and return a response"""
        messages = [
            SystemMessage(
                content=(
                    f"You're an AI Agent and your role is {self.role}. "  
                    f"Your instructions: {self.instructions}"
                )
            )
        ]
        
        # Add user message to conversation
        messages.append(UserMessage(content=user_message))

        # Get AI response and add to conversation
        ai_message = self.llm.invoke(messages)
        messages.append(ai_message)
        # Check if tools were required and execute them until no more tool calls are needed
        while ai_message.tool_calls:
            
            # Process each tool_call in the AI message
            for tool_call in ai_message.tool_calls:
                tool_name = tool_call.function.name
                tool_args = json.loads(tool_call.function.arguments)
                tool_call_id = tool_call.id 
                # Find the matching tool by name
                tool = next((t for t in self.tools if t.name == tool_name), None)
                if tool:
                    # Execute the tool with the provided arguments and get the result
                    tool_result = tool(**tool_args)
                    # Add the tool result to the conversation as a ToolMessage
                    messages.append(ToolMessage(
                        content=str(tool_result),
                        tool_call_id=tool_call_id,
                        name=tool_name
                    ))
        # Get final AI response after tool usage and add to conversation
            ai_message = self.llm.invoke(messages)
            messages.append(ai_message)

        # Print the conversation messages for debugging/observability
        for m in messages:
            print(m)
        return ai_message.content

# %% [markdown]
# ## Testing Your Agent
#
# Once you've implemented the Agent class, test it with different scenarios:

# %% [markdown]
# 1. Basic conversation without tools

# %%
agent = Agent(role="Coding Assistant")
response = agent.invoke("What is Python? Be concise")
print(response)
# Out:
# content="You're an AI Agent and your role is Coding Assistant. Your instructions: Help users with any question" role='system'
# content='What is Python? Be concise' role='user'
# content='Python is a high-level, interpreted programming language known for its readability and simplicity. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python is widely used for web development, data analysis, artificial intelligence, scientific computing, and automation, among other applications.' role='assistant' tool_calls=None
# Python is a high-level, interpreted programming language known for its readability and simplicity. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python is widely used for web development, data analysis, artificial intelligence, scientific computing, and automation, among other applications.

# %% [markdown]
# 2. Create a calculator tool

# %%
@tool
def calculate(expression: str) -> float:
    """Evaluate a mathematical expression"""
    return eval(expression)

# %%
# Create an agent with the calculator tool
math_agent = Agent(
    role="Math Assistant",
    tools=[calculate]
)

# %%
response = math_agent.invoke("What is 23 * 45?")
print(response)
# Out:
# content="You're an AI Agent and your role is Math Assistant. Your instructions: Help users with any question" role='system'
# content='What is 23 * 45?' role='user'
# content=None role='assistant' tool_calls=[ChatCompletionMessageToolCall(id='call_Rmf8QwEnVF7QtXjZARm3C24S', function=Function(arguments='{"expression":"23 * 45"}', name='calculate'), type='function')]
# content='1035' role='tool' tool_call_id='call_Rmf8QwEnVF7QtXjZARm3C24S' name='calculate'
# content='The result of \\( 23 \\times 45 \\) is 1035.' role='assistant' tool_calls=None
# The result of \( 23 \times 45 \) is 1035.

# %%
# Test multiple tool usage
response = math_agent.invoke("If I multiply 3 by 5, what do I get? Then later add 7")
print(response)
# Out:
# content="You're an AI Agent and your role is Math Assistant. Your instructions: Help users with any question" role='system'
# content='If I multiply 3 by 5, what do I get? Then later add 7' role='user'
# content=None role='assistant' tool_calls=[ChatCompletionMessageToolCall(id='call_TPec7UfVpoazMwiBdEvAe5D9', function=Function(arguments='{"expression": "3 * 5"}', name='calculate'), type='function'), ChatCompletionMessageToolCall(id='call_wvjZrSOntr7zOmDTR1yQbc90', function=Function(arguments='{"expression": "(3 * 5) + 7"}', name='calculate'), type='function')]
# content='15' role='tool' tool_call_id='call_TPec7UfVpoazMwiBdEvAe5D9' name='calculate'
# content='22' role='tool' tool_call_id='call_wvjZrSOntr7zOmDTR1yQbc90' name='calculate'
# content='If you multiply 3 by 5, you get 15. If you then add 7 to that result, you get 22.' role='assistant' tool_calls=None
# If you multiply 3 by 5, you get 15. If you then add 7 to that result, you get 22.

# %% [markdown]
# 3. Create a data analyst

# %%
@tool
def get_games(num_games:int=1, top:bool=True) -> str:
    """
    Returns the top or bottom N games with highest or lowest scores.    
    args:
        num_games (int): Number of games to return (default is 1)
        top (bool): If True, return top games, otherwise return bottom (default is True)
    """
    data = [
        {"Game": "The Legend of Zelda: Breath of the Wild", "Platform": "Switch", "Score": 98},
        {"Game": "Super Mario Odyssey", "Platform": "Switch", "Score": 97},
        {"Game": "Metroid Prime", "Platform": "GameCube", "Score": 97},
        {"Game": "Super Smash Bros. Brawl", "Platform": "Wii", "Score": 93},
        {"Game": "Mario Kart 8 Deluxe", "Platform": "Switch", "Score": 92},
        {"Game": "Fire Emblem: Awakening", "Platform": "3DS", "Score": 92},
        {"Game": "Donkey Kong Country Returns", "Platform": "Wii", "Score": 87},
        {"Game": "Luigi's Mansion 3", "Platform": "Switch", "Score": 86},
        {"Game": "Pikmin 3", "Platform": "Wii U", "Score": 85},
        {"Game": "Animal Crossing: New Leaf", "Platform": "3DS", "Score": 88}
    ]
    # Sort the games list by Score
    # If top is True, descending order
    sorted_games = sorted(data, key=lambda x: x['Score'], reverse=top)
    
    # Return the N games
    return sorted_games[:num_games]

# %%
# Create an agent with multiple tools
data_analyst_agent = Agent(
    role="Game Stats Assistant",
    instructions=(
        "You can bring insights about a game dataset based on user questions. "
        "To answer questions about the data, always use get_games first to retrieve the actual records. "
        "When calculating statistics (average, sum, etc.), use get_games(num_games=10) to get all games, "
        "extract the numeric Score values from the result, then pass a valid Python arithmetic expression "
        "with only real numbers to calculate (e.g., '(98+97+85)/3'). "
        "Never pass natural language or variable names to calculate."
    ),
    tools=[get_games, calculate]
)

# %%
response = data_analyst_agent.invoke("What's the best game in the dataset?")
print(response)
# Out:
# content="You're an AI Agent and your role is Game Stats Assistant. Your instructions: You can bring insights about a game dataset based on user questions. To answer questions about the data, always use get_games first to retrieve the actual records. When calculating statistics (average, sum, etc.), use get_games(num_games=10) to get all games, extract the numeric Score values from the result, then pass a valid Python arithmetic expression with only real numbers to calculate (e.g., '(98+97+85)/3'). Never pass natural language or variable names to calculate." role='system'
# content="What's the best game in the dataset?" role='user'
# content=None role='assistant' tool_calls=[ChatCompletionMessageToolCall(id='call_Ui1GxJIQb75Z4751GrHtzIzU', function=Function(arguments='{"num_games":1,"top":true}', name='get_games'), type='function')]
# content="[{'Game': 'The Legend of Zelda: Breath of the Wild', 'Platform': 'Switch', 'Score': 98}]" role='tool' tool_call_id='call_Ui1GxJIQb75Z4751GrHtzIzU' name='get_games'
# content='The best game in the dataset is "The Legend of Zelda: Breath of the Wild" with a score of 98.' role='assistant' tool_calls=None
# The best game in the dataset is "The Legend of Zelda: Breath of the Wild" with a score of 98.

# %%
response = data_analyst_agent.invoke("What's the worst game in the dataset?")
print(response)
# Out:
# content="You're an AI Agent and your role is Game Stats Assistant. Your instructions: You can bring insights about a game dataset based on user questions. To answer questions about the data, always use get_games first to retrieve the actual records. When calculating statistics (average, sum, etc.), use get_games(num_games=10) to get all games, extract the numeric Score values from the result, then pass a valid Python arithmetic expression with only real numbers to calculate (e.g., '(98+97+85)/3'). Never pass natural language or variable names to calculate." role='system'
# content="What's the worst game in the dataset?" role='user'
# content=None role='assistant' tool_calls=[ChatCompletionMessageToolCall(id='call_FhqArNoblv3dcFTo3sbgFDPl', function=Function(arguments='{"num_games":1,"top":false}', name='get_games'), type='function')]
# content="[{'Game': 'Pikmin 3', 'Platform': 'Wii U', 'Score': 85}]" role='tool' tool_call_id='call_FhqArNoblv3dcFTo3sbgFDPl' name='get_games'
# content='The worst game in the dataset is "Pikmin 3" for the Wii U, with a score of 85.' role='assistant' tool_calls=None
# The worst game in the dataset is "Pikmin 3" for the Wii U, with a score of 85.

# %%
response = data_analyst_agent.invoke("What is the average score?")
print(response)
# Out:
# content="You're an AI Agent and your role is Game Stats Assistant. Your instructions: You can bring insights about a game dataset based on user questions. To answer questions about the data, always use get_games first to retrieve the actual records. When calculating statistics (average, sum, etc.), use get_games(num_games=10) to get all games, extract the numeric Score values from the result, then pass a valid Python arithmetic expression with only real numbers to calculate (e.g., '(98+97+85)/3'). Never pass natural language or variable names to calculate." role='system'
# content='What is the average score?' role='user'
# content=None role='assistant' tool_calls=[ChatCompletionMessageToolCall(id='call_AD9KRnkssa8oQx4dPF2F7wMH', function=Function(arguments='{"num_games":10}', name='get_games'), type='function')]
# content='[{\'Game\': \'The Legend of Zelda: Breath of the Wild\', \'Platform\': \'Switch\', \'Score\': 98}, {\'Game\': \'Super Mario Odyssey\', \'Platform\': \'Switch\', \'Score\': 97}, {\'Game\': \'Metroid Prime\', \'Platform\': \'GameCube\', \'Score\': 97}, {\'Game\': \'Super Smash Bros. Brawl\', \'Platform\': \'Wii\', \'Score\': 93}, {\'Game\': \'Mario Kart 8 Deluxe\', \'Platform\': \'Switch\', \'Score\': 92}, {\'Game\': \'Fire Emblem: Awakening\', \'Platform\': \'3DS\', \'Score\': 92}, {\'Game\': \'Animal Crossing: New Leaf\', \'Platform\': \'3DS\', \'Score\': 88}, {\'Game\': \'Donkey Kong Country Returns\', \'Platform\': \'Wii\', \'Score\': 87}, {\'Game\': "Luigi\'s Mansion 3", \'Platform\': \'Switch\', \'Score\': 86}, {\'Game\': \'Pikmin 3\', \'Platform\': \'Wii U\', \'Score\': 85}]' role='tool' tool_call_id='call_AD9KRnkssa8oQx4dPF2F7wMH' name='get_games'
# content=None role='assistant' tool_calls=[ChatCompletionMessageToolCall(id='call_ZVp5A8QJknqgr2BbmZ8hRUAg', function=Function(arguments='{"expression":"(98+97+97+93+92+92+88+87+86+85)/10"}', name='calculate'), type='function')]
# content='91.5' role='tool' tool_call_id='call_ZVp5A8QJknqgr2BbmZ8hRUAg' name='calculate'
# content='The average score is 91.5.' role='assistant' tool_calls=None
# The average score is 91.5.

# %%
response = data_analyst_agent.invoke("What is the distribution of platforms?")
print(response)
# Out:
# content="You're an AI Agent and your role is Game Stats Assistant. Your instructions: You can bring insights about a game dataset based on user questions. To answer questions about the data, always use get_games first to retrieve the actual records. When calculating statistics (average, sum, etc.), use get_games(num_games=10) to get all games, extract the numeric Score values from the result, then pass a valid Python arithmetic expression with only real numbers to calculate (e.g., '(98+97+85)/3'). Never pass natural language or variable names to calculate." role='system'
# content='What is the distribution of platforms?' role='user'
# content=None role='assistant' tool_calls=[ChatCompletionMessageToolCall(id='call_lZA3mBDNOGBzV8vqptdqL8En', function=Function(arguments='{"num_games":10}', name='get_games'), type='function')]
# content='[{\'Game\': \'The Legend of Zelda: Breath of the Wild\', \'Platform\': \'Switch\', \'Score\': 98}, {\'Game\': \'Super Mario Odyssey\', \'Platform\': \'Switch\', \'Score\': 97}, {\'Game\': \'Metroid Prime\', \'Platform\': \'GameCube\', \'Score\': 97}, {\'Game\': \'Super Smash Bros. Brawl\', \'Platform\': \'Wii\', \'Score\': 93}, {\'Game\': \'Mario Kart 8 Deluxe\', \'Platform\': \'Switch\', \'Score\': 92}, {\'Game\': \'Fire Emblem: Awakening\', \'Platform\': \'3DS\', \'Score\': 92}, {\'Game\': \'Animal Crossing: New Leaf\', \'Platform\': \'3DS\', \'Score\': 88}, {\'Game\': \'Donkey Kong Country Returns\', \'Platform\': \'Wii\', \'Score\': 87}, {\'Game\': "Luigi\'s Mansion 3", \'Platform\': \'Switch\', \'Score\': 86}, {\'Game\': \'Pikmin 3\', \'Platform\': \'Wii U\', \'Score\': 85}]' role='tool' tool_call_id='call_lZA3mBDNOGBzV8vqptdqL8En' name='get_games'
# content='Here is the distribution of platforms from the retrieved games:\n\n- **Switch**: 4 games\n- **Wii**: 3 games\n- **3DS**: 2 games\n- **GameCube**: 1 game\n- **Wii U**: 1 game\n\nThis shows that the Switch has the highest representation among the games listed.' role='assistant' tool_calls=None
# Here is the distribution of platforms from the retrieved games:
#
# - **Switch**: 4 games
# - **Wii**: 3 games
# - **3DS**: 2 games
# - **GameCube**: 1 game
# - **Wii U**: 1 game
#
# This shows that the Switch has the highest representation among the games listed.
